# %%
# !pip install supabase
from fetch_odds import get_active_leagues
import os
import requests
from supabase import create_client, Client
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo
# Out:
# ...
#
#    --- ------------------------------------  1/13 [websockets]
#    --- ------------------------------------  1/13 [websockets]
#    --- ------------------------------------  1/13 [websockets]
#    --- ------------------------------------  1/13 [websockets]
#    --- ------------------------------------  1/13 [websockets]
#   Attempting uninstall: pyjwt
#    --- ------------------------------------  1/13 [websockets]
#    ------ ---------------------------------  2/13 [pyjwt]
#     Found existing installation: PyJWT 2.10.1
#    ------ ---------------------------------  2/13 [pyjwt]
#     Uninstalling PyJWT-2.10.1:
#    ------ ---------------------------------  2/13 [pyjwt]
#       Successfully uninstalled PyJWT-2.10.1
#    ------ ---------------------------------  2/13 [pyjwt]
#    ------ ---------------------------------  2/13 [pyjwt]
#    ------ ---------------------------------  2/13 [pyjwt]
#    ------------ ---------------------------  4/13 [hpack]
# ...

# %%
get_active_leagues()
# Out:
# {'1': ['2686',
#   '2438',
#   '199868',
#   '200813',
#   '1740',
#   '217401',
#   '217399',
#   '212572',
#   '212576',
#   '217400',
#   '217562',
#   '199211',
#   '200201',
#   '1978',
#   '1952',
#   '1951',
#   '2037']}
